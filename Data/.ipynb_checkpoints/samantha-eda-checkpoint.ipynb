# %% [markdown]
# # Data Preparation
# ## Step 1 : Data  Sources
#
# In our analysis we look at data  on movie releases from IMDB, and The Numbers to answer questions for a hypothetical movie studio start-up. Our data are contained in the ../zippedData directory of this repo and will need to be unzipped and imported to be useful for this analysis.
#
# ### Why did we choose our data?
#
# We decided to use data from `tn.movie_budgets.csv.gz`, `imdb.title.basics.csv.gz`,`imdb.title.crew.csv.gz` and `imdb.name.basics.csv.gz`. We chose `tn.movie_budgets.csv.gz` because it provided more detailed information about revenue and production costs which allowed us to ask and answer more meaningful questions about the overall return on investment for each film. We also included `imdb.title.basics.csv.gz` in order to take a more detailed look at what _types_ of films performed best over time. Finally, we took a look at the personell files in `imdb.name.basics.csv.gz` and `imdb.title.crew.csv.gz` to answer questions about which directors were involved in successful titles.
#
# First we will import the required packages and build an unzip function to help access our relevant files.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import gzip
from io import StringIO
# %matplotlib inline
import numpy as np

# %%
# This function uses try statements to push through errors and unzip the csv data
def unzip_csv(file_location): 
    file = gzip.open(file_location, 'rb')
    content = file.read()
    file.close()
    try:
        content_str = str(content,'utf-8')
        content_data = StringIO(content_str) 
    except:
        content_str = str(content,'latin-1')
        content_data = StringIO(content_str) 
    try:
        return pd.read_csv(content_data)
    except:
        return pd.read_csv(content_data, sep='\t')

# %%
#for copy paste purposes
# !ls -la zippedData/
# Out:
# total 46512
# drwxr-xr-x  10 samanthabaltodano  staff       320 Jun 23 05:06 .
# drwxr-xr-x  17 samanthabaltodano  staff       544 Jun 23 05:59 ..
# -rw-r--r--@  1 samanthabaltodano  staff      6148 Jun 18 19:29 .DS_Store
# drwxr-xr-x   3 samanthabaltodano  staff        96 Jun 18 10:20 .ipynb_checkpoints
# -rw-r--r--   1 samanthabaltodano  staff    158500 Jun 20 04:53 Untitled.ipynb
# -rw-r--r--@  1 samanthabaltodano  staff     53544 Jun 18 07:08 bom.movie_gross.csv.gz
# -rw-r--r--@  1 samanthabaltodano  staff  18070960 Jun 18 07:08 imdb.name.basics.csv.gz
# -rw-r--r--@  1 samanthabaltodano  staff   3459897 Jun 18 07:08 imdb.title.basics.csv.gz
# -rw-r--r--   1 samanthabaltodano  staff   1898523 Jun 18 07:08 imdb.title.crew.csv.gz
# -rw-r--r--   1 samanthabaltodano  staff    153218 Jun 18 07:08 tn.movie_budgets.csv.gz

# %%
#hard-coding the file-locations and nicknames into a dict for future reference
#Console commands like !ls -la zippedData give a great place to copy pase this

file_locations = [
    'zippedData/bom.movie_gross.csv.gz'
    ,'zippedData/imdb.name.basics.csv.gz'
    ,'zippedData/imdb.title.akas.csv.gz'
    ,'zippedData/imdb.title.basics.csv.gz'
    ,'zippedData/imdb.title.crew.csv.gz'
    ,'zippedData/imdb.title.principals.csv.gz'
    ,'zippedData/imdb.title.ratings.csv.gz'
    ,'zippedData/rt.movie_info.tsv.gz'
    ,'zippedData/rt.reviews.tsv.gz'
    ,'zippedData/tmdb.movies.csv.gz'
    ,'zippedData/tn.movie_budgets.csv.gz'
]

file_nicknames = [
    'gross'
    ,'name'
    ,'akas'
    ,'basics'
    ,'crew'
    ,'principals'
    ,'ratings'
    ,'info'
    ,'reviews'
    ,'movies'
    ,'budget']



#this dicitonary comprehension uses a zip function to smush the two lists together and then parse them into a dict
#we also have a reference for each raw df and its location on the drive.

file_dict = {k:v for k,v in zip(file_nicknames,file_locations)}

# %%
#Importing all the data, commented out data we didn't use

#gross = unzip_csv(file_dict['gross'])
name = unzip_csv(file_dict['name'])
#akas = unzip_csv(file_dict['akas'])
basics = unzip_csv(file_dict['basics'])
#crew = unzip_csv(file_dict['crew'])
#principals = unzip_csv(file_dict['principals'])
#ratings = unzip_csv(file_dict['ratings'])
#info = unzip_csv(file_dict['info'])
#reviews = unzip_csv(file_dict['reviews'])
#movies = unzip_csv(file_dict['movies'])
budgets = unzip_csv(file_dict['budget'])

# %% [markdown]
# ## Step 2: Cleaning the Data
#
# In the next step we take the raw data frames and format the values to their appropriate data types, drop duplicates, null values, and redundant or irrelevant columns. We'll examine the head of our budgets DataFrame below as a starting off point:
#
# ### Budgets

# %%
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
#id column is a redundant index so we're dropping it

budgets.drop('id', axis=1, inplace=True)

# %%
#setting date column to datatime object for use in charts etc.

budgets['release_date'] = pd.to_datetime(budgets['release_date'])

# %%
#stripping any unseen or unknown whitespace from the object locales

budgets.columns.str.strip()
budgets['movie'] = budgets['movie'].str.strip()

# %%
#this function launders the money ;D

def clean_money(budgets_series):
    #the map function applys the .replace to each cell in the given series, x[1:] skips the $
    
    return budgets_series.map(lambda x: int(x[1:].replace(',','')))

# %%
budgets['production_budget'] = clean_money(budgets['production_budget'])
budgets['domestic_gross'] = clean_money(budgets['domestic_gross'])
budgets['worldwide_gross'] = clean_money(budgets['worldwide_gross']);

# %%
budgets.info()
budgets.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   datetime64[ns]
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   int64
#  3   domestic_gross     5782 non-null   int64
#  4   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 226.0+ KB
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
basics.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
basics.tail()
# Out:
#            tconst                                primary_title  \
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 146139            123.0        Drama
# 146140              NaN  Documentary
# 146141              NaN       Comedy
# 146142            116.0          NaN
# 146143              NaN  Documentary

# %%
basics['movie'] = basics['primary_title']

# %%
#we only wanted genres titles, and ttconst for matching to the other file

basics.drop(['primary_title','original_title','start_year'
                ,'runtime_minutes'],axis=1,inplace=True)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   tconst  146144 non-null  object
#  1   genres  140736 non-null  object
#  2   movie   146144 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
#the strip functions remove unwanted whitespace if its lurking in there

basics.columns = basics.columns.str.strip()

for column in list(basics.columns):
    basics[column] = basics[column].str.strip()

# %%
#the dataframe below provides a list of indices that contain a null value in the genre column
#the genre column is very important to our analysis so we'll drop null values

to_drop = basics[basics['genres'].isna()==True].index


#simple drop function will finish the job

basics.drop(to_drop,inplace=True)

# %%
#this .map will apply a .split to all the genres at each "," creating lists within the df

basics['genres'] = basics['genres'].map(lambda x: x.split(","))

# %%
basics['genres'][0]
# Out:
# ['Action', 'Crime', 'Drama']

# %%
basics['genres'][0][1]
# Out:
# 'Crime'

# %%
name.tail()
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#            primary_profession     known_for_titles
# 606643                actress                  NaN
# 606644                actress  tt9090932,tt8737130
# 606645                actress  tt8734436,tt9615610
# 606646               producer                  NaN
# 606647  director,actor,writer            tt8743182

# %%
#dropping these since they're outside the scope of our analysis

name.drop(['nconst','birth_year','death_year',],axis=1,inplace=True)

# %%
name.isnull().sum()
# Out:
# primary_name              0
# primary_profession    51340
# known_for_titles      30204
# dtype: int64

# %%
#this phrase finds null values in either column

to_drop = name[(name['primary_profession'].isna()==True)|
               name['known_for_titles'].isna()==True].index

# %%
name.drop(to_drop,inplace=True)

# %%
#splitting the nested data

name['known_for_titles'] = name['known_for_titles'].map(lambda x: x.split(","))
name['primary_profession'] = name['primary_profession'].map(lambda x: x.split(","));

# %%
name['known_for_titles'][0][0]
# Out:
# 'tt0837562'

# %%
name = name.explode('primary_profession')#, ignore_index='True'

# %%
name.head()
# Out:
#         primary_name  primary_profession  \
# 0  Mary Ellen Bauder       miscellaneous
# 0  Mary Ellen Bauder  production_manager
# 0  Mary Ellen Bauder            producer
# 1       Joseph Bauer            composer
# 1       Joseph Bauer    music_department
#
#                                known_for_titles
# 0  [tt0837562, tt2398241, tt0844471, tt0118553]
# 0  [tt0837562, tt2398241, tt0844471, tt0118553]
# 0  [tt0837562, tt2398241, tt0844471, tt0118553]
# 1  [tt0896534, tt6791238, tt0287072, tt1682940]
# 1  [tt0896534, tt6791238, tt0287072, tt1682940]

# %%
#so here we take a df of all the data with primary professions of producer or director and then ignore the rest. We have 
#duplicate values in the rest of the columns so as long as each movie has a producer or a director, we will have it.

to_keep = name[name.primary_profession =='producer']
name = to_keep
name.head()
# Out:
#              primary_name primary_profession  \
# 0       Mary Ellen Bauder           producer
# 10          Bryan Beasley           producer
# 11     Martine Beauchemin           producer
# 12  Michael Frost Beckner           producer
# 18           Hans Beimler           producer
#
#                                 known_for_titles
# 0   [tt0837562, tt2398241, tt0844471, tt0118553]
# 10  [tt3501180, tt1485100, tt1358897, tt1387162]
# 11  [tt5479010, tt0316463, tt1286159, tt0380732]
# 12  [tt0108171, tt0095953, tt0266987, tt0285332]
# 18  [tt0486657, tt0092455, tt0091129, tt0106145]

# %%
#now we go ahead and explode by known titles so we can continue to narrow in on what we're looking for out of this frame

name = name.explode('known_for_titles')#,ignore_index=True)

# %%
#I couldnt handle the complexity of the multiple jobs in the profedsion column to I only took producers...
#I can drop one of these columns and rename the name column to reflect that these are producers only

name['producer_name'] = name['primary_name']
name.drop(['primary_profession','primary_name'],axis=1, inplace=True)

# %%
name.head()
# Out:
#    known_for_titles      producer_name
# 0         tt0837562  Mary Ellen Bauder
# 0         tt2398241  Mary Ellen Bauder
# 0         tt0844471  Mary Ellen Bauder
# 0         tt0118553  Mary Ellen Bauder
# 10        tt3501180      Bryan Beasley

# %%
num_repeats = name.known_for_titles.value_counts()

# %%
#looks like we have repeat values for the tconst numbers so...

#Theres a lot going on here but I am needing to isolate the values of each individual count of tconst
#using a list comp then dict comp because its such a memory intensive task... for loops with a .append() 
#takes a brick of time.

title_counts = {k:v for k,v in zip(
    num_repeats.index
    , [x for x in num_repeats
      if x > 1]
    )
}
title_counts
# Out:
# {'tt0486531': 221,
#  'tt0452046': 167,
#  'tt0795174': 158,
#  'tt0133302': 135,
#  'tt0203259': 133,
#  'tt0413573': 125,
#  'tt0364845': 120,
#  'tt0206501': 111,
#  'tt1586680': 100,
#  'tt0058796': 89,
#  'tt0094416': 87,
#  'tt0460681': 86,
#  'tt0069658': 80,
#  'tt2741602': 77,
#  'tt1856010': 76,
#  'tt0056758': 75,
#  'tt1844624': 74,
#  'tt0944947': 72,
#  'tt0364151': 71,
#  'tt1378167': 70,
#  'tt0098844': 66,
#  'tt1408430': 66,
#  'tt1345836': 66,
#  'tt1595859': 65,
#  'tt2364582': 64,
#  'tt0804503': 63,
#  'tt0065272': 62,
#  'tt0247082': 62,
#  'tt6111130': 61,
#  'tt0844441': 60,
#  'tt1219024': 59,
#  'tt0460627': 59,
#  'tt0475784': 59,
#  'tt1759761': 58,
#  'tt0806910': 58,
#  'tt1600194': 57,
#  'tt3749900': 57,
#  'tt0418279': 57,
#  'tt1520211': 56,
#  'tt2805096': 56,
#  'tt2372162': 55,
#  'tt1796960': 53,
#  'tt0460649': 53,
#  'tt0092325': 52,
#  'tt0411008': 51,
#  'tt1442437': 50,
#  'tt0108757': 50,
#  'tt0285331': 50,
#  'tt0094481': 50,
#  'tt2402207': 49,
#  'tt0159876': 49,
#  'tt1825683': 49,
#  'tt2249007': 49,
#  'tt0072562': 49,
#  'tt0371746': 48,
#  'tt1567432': 48,
#  'tt2281375': 48,
#  'tt0088580': 47,
#  'tt0146386': 46,
#  'tt4154756': 46,
#  'tt2193021': 46,
#  'tt0141842': 45,
#  'tt0455275': 45,
#  'tt0088512': 45,
#  'tt2788432': 45,
#  'tt1837576': 45,
#  'tt2975590': 45,
#  'tt3566726': 45,
#  'tt4490348': 44,
#  'tt0848228': 44,
#  'tt2015381': 44,
#  'tt2109248': 44,
#  'tt0386676': 44,
#  'tt1405406': 43,
#  'tt0979432': 43,
#  'tt0395843': 43,
#  'tt1124373': 42,
#  'tt2249786': 42,
#  'tt1489428': 42,
#  'tt0083452': 42,
#  'tt1043090': 41,
#  'tt1830617': 41,
#  'tt0903747': 41,
#  'tt0773262': 41,
#  'tt2782710': 41,
#  'tt0796366': 41,
#  'tt0831387': 41,
#  'tt1064899': 41,
#  'tt1375666': 41,
#  'tt2356777': 40,
#  'tt5555260': 40,
#  'tt1839578': 40,
#  'tt0112022': 39,
#  'tt0092322': 39,
#  'tt3107288': 39,
#  'tt3205802': 38,
#  'tt0106179': 38,
#  'tt0441074': 38,
#  'tt3502248': 38,
#  'tt0472954': 38,
#  'tt3743822': 38,
#  'tt3498820': 38,
#  'tt1392170': 38,
#  'tt2261391': 37,
#  'tt0319262': 37,
#  'tt0313043': 37,
#  'tt2575290': 37,
#  'tt3532216': 37,
#  'tt2137109': 37,
#  'tt0367279': 37,
#  'tt0115147': 37,
#  'tt0412142': 37,
#  'tt1826940': 37,
#  'tt1266020': 37,
#  'tt3560084': 37,
#  'tt0062595': 36,
#  'tt2250912': 36,
#  'tt1740299': 36,
#  'tt3032476': 36,
#  'tt0478970': 36,
#  'tt1270798': 35,
#  'tt0092455': 35,
#  'tt0993846': 35,
#  'tt3371366': 35,
#  'tt1119644': 35,
#  'tt1270797': 35,
#  'tt2820852': 35,
#  'tt3322312': 35,
#  'tt0480249': 35,
#  'tt0496424': 35,
#  'tt0468569': 35,
#  'tt1398426': 35,
#  'tt2262532': 35,
#  'tt1477834': 35,
#  'tt0810788': 35,
#  'tt1046173': 34,
#  'tt3843168': 34,
#  'tt5164196': 34,
#  'tt0316654': 34,
#  'tt2357547': 34,
#  'tt4052886': 34,
#  'tt0239195': 34,
#  'tt4154796': 34,
#  'tt3148266': 33,
#  'tt3322314': 33,
#  'tt0425637': 33,
#  'tt0264235': 33,
#  'tt0145487': 33,
#  'tt3514324': 33,
#  'tt2149175': 33,
#  'tt0948470': 33,
#  'tt0306414': 33,
#  'tt4016454': 33,
#  'tt0458339': 33,
#  'tt0387199': 33,
#  'tt2234701': 33,
#  'tt3281796': 33,
#  'tt1840309': 33,
#  'tt0266697': 32,
#  'tt0285335': 32,
#  'tt1327801': 32,
#  'tt0758745': 32,
#  'tt0234215': 32,
#  'tt3014866': 32,
#  'tt0436992': 32,
#  'tt0120201': 32,
#  'tt1843866': 32,
#  'tt0369610': 32,
#  'tt0816711': 32,
#  'tt0407887': 32,
#  'tt0120591': 32,
#  'tt0318224': 32,
#  'tt0770828': 31,
#  'tt3748528': 31,
#  'tt1285016': 31,
#  'tt2527336': 31,
#  'tt1583421': 31,
#  'tt0409459': 31,
#  'tt2431438': 31,
#  'tt0368479': 31,
#  'tt1211956': 30,
#  'tt2575988': 30,
#  'tt1855199': 30,
#  'tt4998350': 30,
#  'tt1399045': 30,
#  'tt0116629': 30,
#  'tt0800369': 30,
#  'tt1024648': 30,
#  'tt1431045': 30,
#  'tt3502262': 30,
#  'tt0372784': 30,
#  'tt3315342': 30,
#  'tt0407304': 30,
#  'tt4474344': 30,
#  'tt1291150': 30,
#  'tt2005374': 30,
#  'tt1663202': 30,
#  'tt6483832': 30,
#  'tt4270492': 30,
#  'tt2103188': 29,
#  'tt1663662': 29,
#  'tt1219289': 29,
#  'tt0324924': 29,
#  'tt1386697': 29,
#  'tt1074638': 29,
#  'tt0944835': 29,
#  'tt1981128': 29,
#  'tt0462322': 29,
#  'tt1706620': 29,
#  'tt0499549': 29,
#  'tt0279600': 29,
#  'tt0489099': 29,
#  'tt0120737': 29,
#  'tt0120685': 29,
#  'tt2231461': 29,
#  'tt2105044': 29,
#  'tt1439629': 29,
#  'tt4630562': 29,
#  'tt0317919': 29,
#  'tt5296406': 28,
#  'tt1845307': 28,
#  'tt0765429': 28,
#  'tt2908446': 28,
#  'tt0285333': 28,
#  'tt0990407': 28,
#  'tt5114356': 28,
#  'tt2467372': 28,
#  'tt0389557': 28,
#  'tt1578873': 28,
#  'tt1440129': 28,
#  'tt1959563': 28,
#  'tt0439100': 28,
#  'tt1298650': 28,
#  'tt1399103': 28,
#  'tt2211129': 28,
#  'tt1934673': 28,
#  'tt0120338': 28,
#  'tt0381061': 28,
#  'tt0149261': 27,
#  'tt0437741': 27,
#  'tt2119532': 27,
#  'tt1951266': 27,
#  'tt0337978': 27,
#  'tt4574334': 27,
#  'tt1327773': 27,
#  'tt0181689': 27,
#  'tt0493464': 27,
#  'tt5827228': 27,
#  'tt3487356': 27,
#  'tt2002718': 27,
#  'tt1259528': 27,
#  'tt1371111': 27,
#  'tt0376994': 27,
#  'tt1190080': 27,
#  'tt0108709': 27,
#  'tt3501074': 27,
#  'tt1276104': 27,
#  'tt1877832': 27,
#  'tt0167260': 27,
#  'tt0159206': 27,
#  'tt2488496': 27,
#  'tt5511582': 27,
#  'tt1408101': 27,
#  'tt0813715': 27,
#  'tt1674771': 26,
#  'tt1800241': 26,
#  'tt4532368': 26,
#  'tt3464902': 26,
#  'tt4209256': 26,
#  'tt0337692': 26,
#  'tt2402101': 26,
#  'tt5024912': 26,
#  'tt6343314': 26,
#  'tt2578508': 26,
#  'tt2058673': 26,
#  'tt0098904': 26,
#  'tt3663490': 26,
#  'tt3501632': 26,
#  'tt0198190': 26,
#  'tt3501584': 26,
#  'tt2234222': 26,
#  'tt0356910': 26,
#  'tt0048845': 26,
#  'tt6473344': 26,
#  'tt0430357': 26,
#  'tt4158110': 26,
#  'tt1320253': 26,
#  'tt1219827': 26,
#  'tt3262006': 26,
#  'tt1409024': 26,
#  'tt2058107': 26,
#  'tt0423652': 26,
#  'tt1836037': 26,
#  'tt0227972': 26,
#  'tt2582782': 26,
#  'tt1392190': 26,
#  'tt7235466': 25,
#  'tt2699128': 25,
#  'tt0408306': 25,
#  'tt3076658': 25,
#  'tt0472043': 25,
#  'tt1650062': 25,
#  'tt1598778': 25,
#  'tt0478304': 25,
#  'tt3896198': 25,
#  'tt0120667': 25,
#  'tt1104001': 25,
#  'tt2528814': 25,
#  'tt1853728': 25,
#  'tt4419214': 25,
#  'tt1229238': 25,
#  'tt0118480': 25,
#  'tt1442462': 25,
#  'tt3783958': 25,
#  'tt0241383': 25,
#  'tt0369179': 25,
#  'tt2267998': 25,
#  'tt2126355': 25,
#  'tt2802850': 25,
#  'tt1817273': 25,
#  'tt0454876': 25,
#  'tt0490215': 25,
#  'tt0185906': 25,
#  'tt0396392': 25,
#  'tt2209764': 25,
#  'tt2891574': 25,
#  'tt1300854': 25,
#  'tt0861689': 25,
#  'tt0118276': 25,
#  'tt0368008': 25,
#  'tt0176357': 25,
#  'tt0098749': 24,
#  'tt0103396': 24,
#  'tt2660888': 24,
#  'tt1979320': 24,
#  'tt5052448': 24,
#  'tt0458525': 24,
#  'tt4981826': 24,
#  'tt0379889': 24,
#  'tt1905041': 24,
#  'tt0800080': 24,
#  'tt0472198': 24,
#  'tt1020072': 24,
#  'tt1798709': 24,
#  'tt1385826': 24,
#  'tt1655461': 24,
#  'tt1196946': 24,
#  'tt0185103': 24,
#  'tt0427327': 24,
#  'tt0120903': 24,
#  'tt0053494': 24,
#  'tt0986263': 24,
#  'tt0297174': 24,
#  'tt1615147': 24,
#  'tt2649554': 24,
#  'tt1596346': 24,
#  'tt0290334': 24,
#  'tt5362988': 24,
#  'tt5834204': 24,
#  'tt0320037': 24,
#  'tt0200276': 24,
#  'tt0437086': 24,
#  'tt0343818': 24,
#  'tt1253864': 24,
#  'tt1250777': 24,
#  'tt0830515': 24,
#  'tt0108778': 24,
#  'tt0285403': 24,
#  'tt1441326': 24,
#  'tt0325980': 24,
#  'tt1951264': 24,
#  'tt1895587': 24,
#  'tt2562232': 24,
#  'tt2345759': 24,
#  'tt1790809': 24,
#  'tt1731141': 23,
#  'tt2402157': 23,
#  'tt0106079': 23,
#  'tt0454848': 23,
#  'tt1670345': 23,
#  'tt4263482': 23,
#  'tt0120815': 23,
#  'tt0375679': 23,
#  'tt2179136': 23,
#  'tt1191111': 23,
#  'tt2262227': 23,
#  'tt2101441': 23,
#  'tt1704573': 23,
#  'tt3949660': 23,
#  'tt0348150': 23,
#  'tt1324999': 23,
#  'tt0882977': 23,
#  'tt0438488': 23,
#  'tt6133466': 23,
#  'tt0790736': 23,
#  'tt5640558': 23,
#  'tt1133985': 23,
#  'tt1707386': 23,
#  'tt0449059': 23,
#  'tt1596343': 23,
#  'tt0842926': 23,
#  'tt1951265': 23,
#  'tt0405336': 23,
#  'tt1272878': 23,
#  'tt5688932': 23,
#  'tt1450321': 23,
#  'tt1103987': 23,
#  'tt3721936': 23,
#  'tt0410975': 23,
#  'tt1059786': 23,
#  'tt2395427': 23,
#  'tt1333125': 23,
#  'tt1626146': 23,
#  'tt2306299': 23,
#  'tt4094300': 23,
#  'tt0896872': 23,
#  'tt3228904': 23,
#  'tt4452630': 23,
#  'tt0964517': 23,
#  'tt4572514': 22,
#  'tt0286486': 22,
#  'tt2283362': 22,
#  'tt1125849': 22,
#  'tt0401729': 22,
#  'tt0359950': 22,
#  'tt0257076': 22,
#  'tt0096697': 22,
#  'tt1340138': 22,
#  'tt3731562': 22,
#  'tt1210819': 22,
#  'tt0277371': 22,
#  'tt0485947': 22,
#  'tt1464540': 22,
#  'tt4288182': 22,
#  'tt1193138': 22,
#  'tt0448011': 22,
#  'tt5016504': 22,
#  'tt3774114': 22,
#  'tt2241351': 22,
#  'tt3337194': 22,
#  'tt1091909': 22,
#  'tt0299658': 22,
#  'tt1291584': 22,
#  'tt1688612': 22,
#  'tt1299368': 22,
#  'tt0298814': 22,
#  'tt1846589': 22,
#  'tt5071412': 22,
#  'tt5095030': 22,
#  'tt4047038': 22,
#  'tt1408253': 22,
#  'tt1872181': 22,
#  'tt0898367': 22,
#  'tt0898266': 22,
#  'tt4669986': 22,
#  'tt2230619': 22,
#  'tt6045840': 22,
#  'tt2103281': 22,
#  'tt1655442': 22,
#  'tt1111422': 22,
#  'tt1060277': 22,
#  'tt4050462': 22,
#  'tt0120611': 22,
#  'tt2707408': 22,
#  'tt0123338': 22,
#  'tt1535108': 22,
#  'tt5463162': 22,
#  'tt0120647': 22,
#  'tt0859163': 22,
#  'tt0416449': 22,
#  'tt0954947': 22,
#  'tt0213149': 21,
#  'tt1091191': 21,
#  'tt1981558': 21,
#  'tt1527186': 21,
#  'tt3316948': 21,
#  'tt2017109': 21,
#  'tt0458481': 21,
#  'tt1621045': 21,
#  'tt2085059': 21,
#  'tt1204975': 21,
#  'tt2379713': 21,
#  'tt1336608': 21,
#  'tt2699110': 21,
#  'tt0068069': 21,
#  'tt0368530': 21,
#  'tt4154664': 21,
#  'tt4824302': 21,
#  'tt1551632': 21,
#  'tt3528906': 21,
#  'tt0974015': 21,
#  'tt0096542': 21,
#  'tt1343092': 21,
#  'tt0985694': 21,
#  'tt1365050': 21,
#  'tt1302006': 21,
#  'tt4635276': 21,
#  'tt1075417': 21,
#  'tt3596174': 21,
#  'tt1628841': 21,
#  'tt7349662': 21,
#  'tt1495708': 21,
#  'tt1242460': 21,
#  'tt1469304': 21,
#  'tt4560436': 21,
#  'tt2543328': 21,
#  'tt0822847': 21,
#  'tt1211837': 21,
#  'tt0110912': 21,
#  'tt1862079': 21,
#  'tt1464580': 21,
#  'tt0977855': 21,
#  'tt1478338': 21,
#  'tt0790712': 21,
#  'tt0382992': 21,
#  'tt2304933': 21,
#  'tt1055369': 21,
#  'tt1022603': 21,
#  'tt3829266': 21,
#  'tt0947798': 21,
#  'tt1228705': 21,
#  'tt1093357': 21,
#  'tt0246578': 21,
#  'tt0426459': 21,
#  'tt0238784': 21,
#  'tt0790636': 21,
#  'tt0437745': 21,
#  'tt0124932': 21,
#  'tt4643084': 21,
#  'tt3551096': 21,
#  'tt0113277': 21,
#  'tt3827540': 21,
#  'tt0114369': 21,
#  'tt4364202': 21,
#  'tt0277296': 21,
#  'tt4833364': 21,
#  'tt1637574': 21,
#  'tt0340855': 21,
#  'tt3460252': 21,
#  'tt1245526': 21,
#  'tt3072482': 21,
#  'tt2400463': 20,
#  'tt0387564': 20,
#  'tt0275140': 20,
#  'tt5206770': 20,
#  'tt3553976': 20,
#  'tt6265828': 20,
#  'tt3006802': 20,
#  'tt1020109': 20,
#  'tt0119094': 20,
#  'tt0431197': 20,
#  'tt0139654': 20,
#  'tt2910274': 20,
#  'tt1587310': 20,
#  'tt1632701': 20,
#  'tt0118375': 20,
#  'tt2120120': 20,
#  'tt1500910': 20,
#  'tt1856101': 20,
#  'tt1100089': 20,
#  'tt1490017': 20,
#  'tt5519340': 20,
#  'tt0449088': 20,
#  'tt1959490': 20,
#  'tt1099212': 20,
#  'tt0133093': 20,
#  'tt0407362': 20,
#  'tt0102685': 20,
#  'tt1355631': 20,
#  'tt0450314': 20,
#  'tt2402927': 20,
#  'tt0104797': 20,
#  'tt3327536': 20,
#  'tt4846340': 20,
#  'tt3859618': 20,
#  'tt1483013': 20,
#  'tt4779682': 20,
#  'tt0206634': 20,
#  'tt0367027': 20,
#  'tt3488298': 20,
#  'tt4425200': 20,
#  'tt1791528': 20,
#  'tt0114558': 20,
#  'tt5420376': 20,
#  'tt1045658': 20,
#  'tt1037705': 20,
#  'tt1041677': 20,
#  'tt0960144': 20,
#  'tt0133152': 20,
#  'tt1843230': 20,
#  'tt5348176': 20,
#  'tt1935896': 20,
#  'tt1663676': 20,
#  'tt1124035': 20,
#  'tt2158640': 20,
#  'tt0780504': 20,
#  'tt1631867': 20,
#  'tt0838247': 20,
#  'tt4093826': 20,
#  'tt1155076': 20,
#  'tt2302755': 20,
#  'tt2024544': 20,
#  'tt2147225': 20,
#  'tt1619029': 20,
#  'tt0171804': 20,
#  'tt0129387': 20,
#  'tt0116695': 20,
#  'tt2543164': 19,
#  'tt2872718': 19,
#  'tt2350496': 19,
#  'tt2637276': 19,
#  'tt0158552': 19,
#  'tt0816462': 19,
#  'tt1201607': 19,
#  'tt3659388': 19,
#  'tt1645080': 19,
#  'tt1454029': 19,
#  'tt1492179': 19,
#  'tt0241527': 19,
#  'tt1013752': 19,
#  'tt1292566': 19,
#  'tt4015500': 19,
#  'tt1394280': 19,
#  'tt1677720': 19,
#  'tt0296572': 19,
#  'tt1972591': 19,
#  'tt0181865': 19,
#  'tt1637688': 19,
#  'tt2101341': 19,
#  'tt0887912': 19,
#  'tt2294449': 19,
#  'tt1001508': 19,
#  'tt1586752': 19,
#  'tt0485985': 19,
#  'tt0109830': 19,
#  'tt1980003': 19,
#  'tt1855325': 19,
#  'tt3044834': 19,
#  'tt2071758': 19,
#  'tt0443272': 19,
#  'tt0468489': 19,
#  'tt1673434': 19,
#  'tt1502712': 19,
#  'tt2848292': 19,
#  'tt1617661': 19,
#  'tt1194173': 19,
#  'tt5171438': 19,
#  'tt4952142': 19,
#  'tt7125860': 19,
#  'tt4428122': 19,
#  'tt8804580': 19,
#  'tt7959026': 19,
#  'tt0430308': 19,
#  'tt1034415': 19,
#  'tt0114857': 19,
#  'tt0451279': 19,
#  'tt1023114': 19,
#  'tt0997152': 19,
#  'tt2984576': 19,
#  'tt0370263': 19,
#  'tt6998518': 19,
#  'tt0346491': 19,
#  'tt1318514': 19,
#  'tt1764651': 19,
#  'tt1119646': 19,
#  'tt3152624': 19,
#  'tt0808096': 19,
#  'tt0385726': 19,
#  'tt0181852': 19,
#  'tt0258068': 19,
#  'tt2334649': 19,
#  'tt1127715': 19,
#  'tt1837492': 19,
#  'tt1386703': 19,
#  'tt3063516': 19,
#  'tt2088003': 19,
#  'tt1188729': 19,
#  'tt0822854': 19,
#  'tt0106697': 19,
#  'tt0478134': 18,
#  'tt0280707': 18,
#  'tt1608290': 18,
#  'tt1189340': 18,
#  'tt2179116': 18,
#  'tt1860357': 18,
#  'tt1502407': 18,
#  'tt0808151': 18,
#  'tt0405159': 18,
#  'tt0942385': 18,
#  'tt2647544': 18,
#  'tt2883512': 18,
#  'tt1413492': 18,
#  'tt0455944': 18,
#  'tt2193041': 18,
#  'tt2578560': 18,
#  'tt0121766': 18,
#  'tt0399295': 18,
#  'tt1620935': 18,
#  'tt2076566': 18,
#  'tt1798684': 18,
#  'tt0325710': 18,
#  'tt2661044': 18,
#  'tt0772137': 18,
#  'tt2017038': 18,
#  'tt0878804': 18,
#  'tt6966692': 18,
#  'tt0884732': 18,
#  'tt2461150': 18,
#  'tt0245712': 18,
#  'tt1758692': 18,
#  'tt0172495': 18,
#  'tt2123146': 18,
#  'tt1658837': 18,
#  'tt1800302': 18,
#  'tt0457430': 18,
#  'tt4577466': 18,
#  'tt5034326': 18,
#  'tt2932536': 18,
#  'tt0382491': 18,
#  'tt3172532': 18,
#  'tt0106145': 18,
#  'tt2170584': 18,
#  'tt1853739': 18,
#  'tt0167261': 18,
#  'tt1486834': 18,
#  'tt0892255': 18,
#  'tt3312830': 18,
#  'tt5592146': 18,
#  'tt5027774': 18,
#  'tt2879552': 18,
#  'tt0396269': 18,
#  'tt5574490': 18,
#  'tt0450259': 18,
#  'tt1723121': 18,
#  'tt0248654': 18,
#  'tt2006295': 18,
#  'tt0375063': 18,
#  'tt0166924': 18,
#  'tt3450958': 18,
#  'tt0126029': 18,
#  'tt2679042': 18,
#  'tt0343660': 18,
#  'tt1462900': 18,
#  'tt0457400': 18,
#  'tt0401792': 18,
#  'tt1430132': 18,
#  'tt0758746': 18,
#  'tt0295178': 18,
#  'tt1172570': 18,
#  'tt0362270': 18,
#  'tt4522400': 18,
#  'tt0787524': 18,
#  'tt2404463': 18,
#  'tt1532503': 18,
#  'tt2322441': 18,
#  'tt1790885': 18,
#  'tt0421715': 18,
#  'tt4975856': 18,
#  'tt0463985': 18,
#  'tt0467406': 18,
#  'tt1282140': 18,
#  'tt1321870': 18,
#  'tt1517451': 18,
#  'tt0118749': 18,
#  'tt0390699': 18,
#  'tt0192917': 18,
#  'tt1711425': 18,
#  'tt0115285': 18,
#  'tt0294870': 17,
#  'tt2025690': 17,
#  'tt8416494': 17,
#  'tt0418819': 17,
#  'tt1185836': 17,
#  'tt0409904': 17,
#  'tt4651520': 17,
#  'tt1615065': 17,
#  'tt1542344': 17,
#  'tt1403177': 17,
#  'tt0389722': 17,
#  'tt0244365': 17,
#  'tt1053424': 17,
#  'tt1552224': 17,
#  'tt2334879': 17,
#  'tt6053438': 17,
#  'tt0369339': 17,
#  'tt4236770': 17,
#  'tt0955308': 17,
#  'tt0163651': 17,
#  'tt3381008': 17,
#  'tt5460226': 17,
#  'tt1981677': 17,
#  'tt1433108': 17,
#  'tt1458175': 17,
#  'tt0265086': 17,
#  'tt1748122': 17,
#  'tt3890160': 17,
#  'tt0117998': 17,
#  'tt1568346': 17,
#  'tt0816692': 17,
#  'tt3499096': 17,
#  'tt1399683': 17,
#  'tt1298649': 17,
#  'tt0181875': 17,
#  'tt0168629': 17,
#  'tt3922818': 17,
#  'tt4769836': 17,
#  'tt1179031': 17,
#  'tt2396589': 17,
#  'tt0327850': 17,
#  'tt0162346': 17,
#  'tt2345481': 17,
#  'tt3091166': 17,
#  'tt4254242': 17,
#  'tt1242422': 17,
#  'tt1723816': 17,
#  'tt1213641': 17,
#  'tt0388795': 17,
#  'tt5651844': 17,
#  'tt0044265': 17,
#  'tt0408790': 17,
#  'tt4698684': 17,
#  'tt0140352': 17,
#  'tt2884206': 17,
#  'tt1598642': 17,
#  'tt1225901': 17,
#  'tt3079380': 17,
#  'tt0232500': 17,
#  'tt3628704': 17,
#  'tt0373883': 17,
#  'tt0433387': 17,
#  'tt6294822': 17,
#  'tt0399201': 17,
#  'tt0374455': 17,
#  'tt0289879': 17,
#  'tt3560148': 17,
#  'tt0120812': 17,
#  'tt1418377': 17,
#  'tt0450232': 17,
#  'tt0107290': 17,
#  'tt0413300': 17,
#  'tt0162065': 17,
#  'tt1175709': 17,
#  'tt0379725': 17,
#  'tt2261227': 17,
#  'tt1517260': 17,
#  'tt1655441': 17,
#  'tt2729716': 17,
#  'tt0318627': 17,
#  'tt2382396': 17,
#  'tt0302886': 17,
#  'tt1405365': 17,
#  'tt1606375': 17,
#  'tt0445934': 17,
#  'tt0805669': 17,
#  'tt0425061': 17,
#  'tt0360717': 17,
#  'tt0891100': 17,
#  'tt0383574': 17,
#  'tt0199257': 17,
#  'tt0204946': 17,
#  'tt0453467': 17,
#  'tt0465234': 17,
#  'tt0395251': 17,
#  'tt0460829': 17,
#  'tt0305357': 17,
#  'tt1435513': 17,
#  'tt0186566': 17,
#  'tt0840361': 17,
#  'tt0361748': 17,
#  'tt0435651': 17,
#  'tt1972571': 17,
#  'tt0094415': 17,
#  'tt0395584': 17,
#  'tt1172233': 17,
#  'tt0120679': 17,
#  'tt0335345': 17,
#  'tt0196229': 17,
#  'tt0401711': 17,
#  'tt1220634': 17,
#  'tt0277434': 17,
#  'tt1136608': 17,
#  'tt3039472': 17,
#  'tt3564858': 17,
#  'tt0308055': 17,
#  'tt4034228': 17,
#  'tt0929632': 17,
#  'tt0374900': 17,
#  'tt0096555': 17,
#  'tt1637727': 17,
#  'tt0132347': 17,
#  'tt1439572': 17,
#  'tt0443489': 17,
#  'tt0162677': 17,
#  'tt2316411': 17,
#  'tt3967856': 17,
#  'tt1974419': 16,
#  'tt0408839': 16,
#  'tt5813366': 16,
#  'tt5011816': 16,
#  'tt1560747': 16,
#  'tt0372183': 16,
#  'tt3468798': 16,
#  'tt5649144': 16,
#  'tt0810922': 16,
#  'tt2198243': 16,
#  'tt0852713': 16,
#  'tt6470478': 16,
#  'tt2096672': 16,
#  'tt4903242': 16,
#  'tt2322641': 16,
#  'tt1737796': 16,
#  'tt0490086': 16,
#  'tt0360486': 16,
#  'tt0250494': 16,
#  'tt0803096': 16,
#  'tt0295701': 16,
#  'tt1815862': 16,
#  'tt0118571': 16,
#  'tt0366551': 16,
#  'tt4287320': 16,
#  'tt0266465': 16,
#  'tt1895315': 16,
#  'tt0963178': 16,
#  'tt1343727': 16,
#  'tt1340800': 16,
#  'tt3741700': 16,
#  'tt0157246': 16,
#  'tt0499556': 16,
#  'tt0970416': 16,
#  'tt1911644': 16,
#  'tt0472399': 16,
#  'tt3758172': 16,
#  'tt0112004': 16,
#  'tt0422401': 16,
#  'tt4801232': 16,
#  'tt0144084': 16,
#  'tt1596363': 16,
#  'tt3885690': 16,
#  'tt4145054': 16,
#  'tt4217392': 16,
#  'tt1519931': 16,
#  'tt0477348': 16,
#  'tt0390022': 16,
#  'tt2948160': 16,
#  'tt0815236': 16,
#  'tt4168956': 16,
#  'tt0268978': 16,
#  'tt1176740': 16,
#  'tt2397255': 16,
#  'tt0851851': 16,
#  'tt0172156': 16,
#  'tt0483607': 16,
#  'tt0343737': 16,
#  'tt3491962': 16,
#  'tt1034032': 16,
#  'tt0800325': 16,
#  'tt0180093': 16,
#  'tt4701182': 16,
#  'tt0119822': 16,
#  'tt3230454': 16,
#  'tt4781612': 16,
#  'tt2280066': 16,
#  'tt2140379': 16,
#  'tt0440963': 16,
#  'tt0118421': 16,
#  'tt0480255': 16,
#  'tt1790864': 16,
#  'tt0381707': 16,
#  'tt7587890': 16,
#  'tt1637725': 16,
#  'tt3228420': 16,
#  'tt1536537': 16,
#  'tt3263904': 16,
#  'tt0367882': 16,
#  'tt0810819': 16,
#  'tt4786824': 16,
#  'tt0402022': 16,
#  'tt1210166': 16,
#  'tt0078788': 16,
#  'tt2375692': 16,
#  'tt0844479': 16,
#  'tt0264395': 16,
#  'tt0862467': 16,
#  'tt0118884': 16,
#  'tt0945513': 16,
#  'tt0416044': 16,
#  'tt3397884': 16,
#  'tt1523267': 16,
#  'tt2278388': 16,
#  'tt0119654': 16,
#  'tt1615160': 16,
#  'tt1591479': 16,
#  'tt0452623': 16,
#  'tt0388574': 16,
#  'tt6634854': 16,
#  'tt0313911': 16,
#  'tt0434409': 16,
#  'tt1699748': 16,
#  'tt1764234': 16,
#  'tt0350258': 16,
#  ...}

# %%
name['known_for_titles']
# Out:
# 0         tt0837562
# 0         tt2398241
# 0         tt0844471
# 0         tt0118553
# 10        tt3501180
#             ...
# 606619    tt8697454
# 606634    tt0306913
# 606634    tt8726188
# 606635    tt8728296
# 606636    tt8706386
# Name: known_for_titles, Length: 477089, dtype: object

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140736 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   tconst  140736 non-null  object
#  1   genres  140736 non-null  object
#  2   movie   140736 non-null  object
# dtypes: object(3)
# memory usage: 9.3+ MB

# %%
name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477089 entries, 0 to 606636
# Data columns (total 2 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   known_for_titles  477089 non-null  object
#  1   producer_name     477089 non-null  object
# dtypes: object(2)
# memory usage: 10.9+ MB

# %%
#the merge method is much more versatile than the join method so im using it for all the merges
#I chose a left join and started with basics here since its the smaller of the two frames
#a left join will use keys from the left table to match to the right and keep those records even if 
#theres no data on the right table.

df2 = basics.merge(name,how='left', left_on='tconst', right_on='known_for_titles')

# %% [markdown]
# Start of my code

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140736 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   tconst  140736 non-null  object
#  1   genres  140736 non-null  object
#  2   movie   140736 non-null  object
# dtypes: object(3)
# memory usage: 9.3+ MB

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   datetime64[ns]
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   int64
#  3   domestic_gross     5782 non-null   int64
#  4   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 226.0+ KB

# %%
#merge the budgets and basics dataframes to compare gross by genre
df3 = budgets.merge(basics,how='left', left_on='movie', right_on='movie')
df3.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000       760507625       2776345279  tt1775309
# 1          410600000       241063875       1045663875  tt1298650
# 2          350000000        42762350        149762350  tt6565702
# 3          330600000       459005868       1403013963  tt2395427
# 4          317000000       620181382       1316721747        NaN
#
#                          genres
# 0                      [Horror]
# 1  [Action, Adventure, Fantasy]
# 2   [Action, Adventure, Sci-Fi]
# 3   [Action, Adventure, Sci-Fi]
# 4                           NaN

# %%
#find which columns contain missing data
df3.isna().sum()
# Out:
# release_date            0
# movie                   0
# production_budget       0
# domestic_gross          0
# worldwide_gross         0
# tconst               3419
# genres               3419
# dtype: int64

# %%
#Remove any row that has a NaN value. Note that NaN values are only in genre and tconst ^
df3.dropna(inplace=True)
df3.head
# Out:
# <bound method NDFrame.head of      release_date                                        movie  \
# 0      2009-12-18                                       Avatar
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2019-06-07                                 Dark Phoenix
# 3      2015-05-01                      Avengers: Age of Ultron
# 6      2018-04-27                       Avengers: Infinity War
# ...           ...                                          ...
# 7146   2006-04-28                                        Clean
# 7147   2001-07-06                                         Cure
# 7152   2012-01-13                                    Newlyweds
# 7157   2018-12-31                                       Red 11
# 7160   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross     tconst  \
# 0             425000000       760507625       2776345279  tt1775309
# 1             410600000       241063875       1045663875  tt1298650
# 2             350000000        42762350        149762350  tt6565702
# 3             330600000       459005868       1403013963  tt2395427
# 6             300000000       678815482       2048134200  tt4154756
# ...                 ...             ...              ...        ...
# 7146              10000          138711           138711  tt6619196
# 7147              10000           94596            94596  tt1872026
# 7152               9000            4584             4584  tt1880418
# 7157               7000               0                0  tt7837402
# 7160               1400               0                0  tt2107644
#
#                             genres
# 0                         [Horror]
# 1     [Action, Adventure, Fantasy]
# 2      [Action, Adventure, Sci-Fi]
# 3      [Action, Adventure, Sci-Fi]
# 6      [Action, Adventure, Sci-Fi]
# ...                            ...
# 7146       [Comedy, Drama, Horror]
# 7147                       [Drama]
# 7152               [Comedy, Drama]
# 7157    [Horror, Sci-Fi, Thriller]
# 7160     [Drama, Horror, Thriller]
#
# [3743 rows x 7 columns]>

# %%
df3.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 6   2018-04-27                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000       760507625       2776345279  tt1775309
# 1          410600000       241063875       1045663875  tt1298650
# 2          350000000        42762350        149762350  tt6565702
# 3          330600000       459005868       1403013963  tt2395427
# 6          300000000       678815482       2048134200  tt4154756
#
#                          genres
# 0                      [Horror]
# 1  [Action, Adventure, Fantasy]
# 2   [Action, Adventure, Sci-Fi]
# 3   [Action, Adventure, Sci-Fi]
# 6   [Action, Adventure, Sci-Fi]

# %%
df3.shape
# Out:
# (3743, 7)

# %%
#remove duplicate movie titles from my data
df3_new = df3.drop_duplicates(subset='movie', keep='first')
#take a look at how many columns are left
df3_new.shape
# Out:
# (2299, 7)

# %%
df3_new.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 6   2018-04-27                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000       760507625       2776345279  tt1775309
# 1          410600000       241063875       1045663875  tt1298650
# 2          350000000        42762350        149762350  tt6565702
# 3          330600000       459005868       1403013963  tt2395427
# 6          300000000       678815482       2048134200  tt4154756
#
#                          genres
# 0                      [Horror]
# 1  [Action, Adventure, Fantasy]
# 2   [Action, Adventure, Sci-Fi]
# 3   [Action, Adventure, Sci-Fi]
# 6   [Action, Adventure, Sci-Fi]

# %%
#create a column to show the rate of return based on only domestic_gross for each movie
df3_new['roi_domestic'] = (df3_new['domestic_gross'] - df3_new['production_budget']) / df3_new['production_budget'] * 100
df3_new.head()
# Out:
# <ipython-input-52-1d11ea12b639>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_new['roi_domestic'] = (df3_new['domestic_gross'] - df3_new['production_budget']) / df3_new['production_budget'] * 100
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 6   2018-04-27                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000       760507625       2776345279  tt1775309
# 1          410600000       241063875       1045663875  tt1298650
# 2          350000000        42762350        149762350  tt6565702
# 3          330600000       459005868       1403013963  tt2395427
# 6          300000000       678815482       2048134200  tt4154756
#
#                          genres  roi_domestic
# 0                      [Horror]     78.942971
# 1  [Action, Adventure, Fantasy]    -41.289850
# 2   [Action, Adventure, Sci-Fi]    -87.782186
# 3   [Action, Adventure, Sci-Fi]     38.840250
# 6   [Action, Adventure, Sci-Fi]    126.271827

# %%
df3_new
# Out:
#      release_date                                        movie  \
# 0      2009-12-18                                       Avatar
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2019-06-07                                 Dark Phoenix
# 3      2015-05-01                      Avengers: Age of Ultron
# 6      2018-04-27                       Avengers: Infinity War
# ...           ...                                          ...
# 7146   2006-04-28                                        Clean
# 7147   2001-07-06                                         Cure
# 7152   2012-01-13                                    Newlyweds
# 7157   2018-12-31                                       Red 11
# 7160   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross     tconst  \
# 0             425000000       760507625       2776345279  tt1775309
# 1             410600000       241063875       1045663875  tt1298650
# 2             350000000        42762350        149762350  tt6565702
# 3             330600000       459005868       1403013963  tt2395427
# 6             300000000       678815482       2048134200  tt4154756
# ...                 ...             ...              ...        ...
# 7146              10000          138711           138711  tt6619196
# 7147              10000           94596            94596  tt1872026
# 7152               9000            4584             4584  tt1880418
# 7157               7000               0                0  tt7837402
# 7160               1400               0                0  tt2107644
#
#                             genres  roi_domestic
# 0                         [Horror]     78.942971
# 1     [Action, Adventure, Fantasy]    -41.289850
# 2      [Action, Adventure, Sci-Fi]    -87.782186
# 3      [Action, Adventure, Sci-Fi]     38.840250
# 6      [Action, Adventure, Sci-Fi]    126.271827
# ...                            ...           ...
# 7146       [Comedy, Drama, Horror]   1287.110000
# 7147                       [Drama]    845.960000
# 7152               [Comedy, Drama]    -49.066667
# 7157    [Horror, Sci-Fi, Thriller]   -100.000000
# 7160     [Drama, Horror, Thriller]   -100.000000
#
# [2299 rows x 8 columns]

# %%
#create a column showing rate of return using qorldwide_gross for each movie
df3_new['roi_worldwide'] = (df3_new['worldwide_gross'] - df3_new['production_budget']) / df3_new['production_budget'] * 100
df3_new.head()
# Out:
# <ipython-input-54-3e0e7aec4436>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_new['roi_worldwide'] = (df3_new['worldwide_gross'] - df3_new['production_budget']) / df3_new['production_budget'] * 100
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 6   2018-04-27                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000       760507625       2776345279  tt1775309
# 1          410600000       241063875       1045663875  tt1298650
# 2          350000000        42762350        149762350  tt6565702
# 3          330600000       459005868       1403013963  tt2395427
# 6          300000000       678815482       2048134200  tt4154756
#
#                          genres  roi_domestic  roi_worldwide
# 0                      [Horror]     78.942971     553.257713
# 1  [Action, Adventure, Fantasy]    -41.289850     154.667286
# 2   [Action, Adventure, Sci-Fi]    -87.782186     -57.210757
# 3   [Action, Adventure, Sci-Fi]     38.840250     324.384139
# 6   [Action, Adventure, Sci-Fi]    126.271827     582.711400

# %%
#I am sorting my worldwide roi column in descending order
final_df_worldwide = df3_new.sort_values(by=['roi_worldwide'], ascending=False)
final_df_worldwide
# Out:
#      release_date                            movie  production_budget  \
# 7047   2015-07-10                      The Gallows             100000
# 6600   1942-08-13                            Bambi             858000
# 6445   1976-11-21                            Rocky            1000000
# 6332   1937-12-21  Snow White and the Seven Dwarfs            1488000
# 6447   2012-01-06                 The Devil Inside            1000000
# ...           ...                              ...                ...
# 5394   2015-01-09           Let's Kill Ward's Wife            5000000
# 5392   2014-08-18                       Henry & Me            5000000
# 5391   2014-11-21                         Reach Me            5000000
# 2822   2019-12-31                           Reagan           25000000
# 7160   2015-09-29             A Plague So Pleasant               1400
#
#       domestic_gross  worldwide_gross     tconst                       genres  \
# 7047        22764410         41656474  tt2309260  [Horror, Mystery, Thriller]
# 6600       102797000        268000000  tt2668120     [Biography, Documentary]
# 6445       117235147        225000000  tt3080284      [Action, Comedy, Drama]
# 6332       184925486        184925486  tt7821084          [Animation, Family]
# 6447        53262945        101759490  tt1560985                     [Horror]
# ...              ...              ...        ...                          ...
# 5394               0                0  tt2980708              [Comedy, Crime]
# 5392               0                0  tt1460798          [Animation, Family]
# 5391               0                0  tt0959306       [Comedy, Crime, Drama]
# 2822               0                0  tt1822382     [Biography, Documentary]
# 7160               0                0  tt2107644    [Drama, Horror, Thriller]
#
#       roi_domestic  roi_worldwide
# 7047  22664.410000   41556.474000
# 6600  11881.002331   31135.431235
# 6445  11623.514700   22400.000000
# 6332  12327.788038   12327.788038
# 6447   5226.294500   10075.949000
# ...            ...            ...
# 5394   -100.000000    -100.000000
# 5392   -100.000000    -100.000000
# 5391   -100.000000    -100.000000
# 2822   -100.000000    -100.000000
# 7160   -100.000000    -100.000000
#
# [2299 rows x 9 columns]

# %%
#the genres for each movie are in a list. I need to seperate the genres so i can perform further analysis
final_df_worldwide = final_df_worldwide.explode('genres')#,ignore_index=True)

# %%
final_df_worldwide.head()
# Out:
#      release_date        movie  production_budget  domestic_gross  \
# 7047   2015-07-10  The Gallows             100000        22764410
# 7047   2015-07-10  The Gallows             100000        22764410
# 7047   2015-07-10  The Gallows             100000        22764410
# 6600   1942-08-13        Bambi             858000       102797000
# 6600   1942-08-13        Bambi             858000       102797000
#
#       worldwide_gross     tconst       genres  roi_domestic  roi_worldwide
# 7047         41656474  tt2309260       Horror  22664.410000   41556.474000
# 7047         41656474  tt2309260      Mystery  22664.410000   41556.474000
# 7047         41656474  tt2309260     Thriller  22664.410000   41556.474000
# 6600        268000000  tt2668120    Biography  11881.002331   31135.431235
# 6600        268000000  tt2668120  Documentary  11881.002331   31135.431235

# %%
final_df_worldwide.shape
# Out:
# (5310, 9)

# %%
final_df_worldwide['genres'].unique() #taking a look at unique genres in the genres column
# Out:
# array(['Horror', 'Mystery', 'Thriller', 'Biography', 'Documentary',
#        'Action', 'Comedy', 'Drama', 'Animation', 'Family', 'Crime',
#        'Romance', 'Sport', 'Fantasy', 'War', 'Music', 'Sci-Fi',
#        'Adventure', 'History', 'Musical', 'Western', 'News'], dtype=object)

# %%
#filter my datetime column to only show movies released in the last 10 years (since 2011)
filtered_df = final_df_worldwide.loc[(final_df_worldwide['release_date'] >= '2011-01-01')]
#i know this worked because my rows went down from 5310 to 3945
filtered_df
# Out:
#      release_date                 movie  production_budget  domestic_gross  \
# 7047   2015-07-10           The Gallows             100000        22764410
# 7047   2015-07-10           The Gallows             100000        22764410
# 7047   2015-07-10           The Gallows             100000        22764410
# 6447   2012-01-06      The Devil Inside            1000000        53262945
# 6266   2011-04-01             Insidious            1500000        54009150
# ...           ...                   ...                ...             ...
# 2822   2019-12-31                Reagan           25000000               0
# 2822   2019-12-31                Reagan           25000000               0
# 7160   2015-09-29  A Plague So Pleasant               1400               0
# 7160   2015-09-29  A Plague So Pleasant               1400               0
# 7160   2015-09-29  A Plague So Pleasant               1400               0
#
#       worldwide_gross     tconst       genres  roi_domestic  roi_worldwide
# 7047         41656474  tt2309260       Horror    22664.4100   41556.474000
# 7047         41656474  tt2309260      Mystery    22664.4100   41556.474000
# 7047         41656474  tt2309260     Thriller    22664.4100   41556.474000
# 6447        101759490  tt1560985       Horror     5226.2945   10075.949000
# 6266         99870886  tt1591095       Horror     3500.6100    6558.059067
# ...               ...        ...          ...           ...            ...
# 2822                0  tt1822382    Biography     -100.0000    -100.000000
# 2822                0  tt1822382  Documentary     -100.0000    -100.000000
# 7160                0  tt2107644        Drama     -100.0000    -100.000000
# 7160                0  tt2107644       Horror     -100.0000    -100.000000
# 7160                0  tt2107644     Thriller     -100.0000    -100.000000
#
# [3945 rows x 9 columns]

# %%
# filtered_df.set_index(keys=['genres'], drop=False,inplace=True)

# %%
genres=filtered_df['genres'].unique().tolist()
horror = filtered_df.loc[filtered_df.genres=='Horror']
mystery = filtered_df.loc[filtered_df.genres=='Mystery']
comedy = filtered_df.loc[filtered_df.genres=='Comedy']
romance = filtered_df.loc[filtered_df.genres=='Romance']
sport = filtered_df.loc[filtered_df.genres=='Sport']
drama = filtered_df.loc[filtered_df.genres=='Drama']
action = filtered_df.loc[filtered_df.genres=='Action']
biography = filtered_df.loc[filtered_df.genres=='Biography']
fantasy = filtered_df.loc[filtered_df.genres=='Fantasy']
music = filtered_df.loc[filtered_df.genres=='Music']
documentary = filtered_df.loc[filtered_df.genres=='Documentary']
crime = filtered_df.loc[filtered_df.genres=='Crime']
scifi = filtered_df.loc[filtered_df.genres=='Sci-Fi']
adventure = filtered_df.loc[filtered_df.genres=='Adventure']
animation = filtered_df.loc[filtered_df.genres=='Animation']
family = filtered_df.loc[filtered_df.genres=='Family']
history = filtered_df.loc[filtered_df.genres=='History']
musical = filtered_df.loc[filtered_df.genres=='Musical']
western = filtered_df.loc[filtered_df.genres=='Western']
war = filtered_df.loc[filtered_df.genres=='War']
news = filtered_df.loc[filtered_df.genres=='News']
thriller = filtered_df.loc[filtered_df.genres=='Thriller']

# %%
thriller.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       2.830000e+02    2.830000e+02     2.830000e+02    283.000000
# mean        2.687958e+07    3.528768e+07     9.488360e+07    167.263049
# std         4.015476e+07    5.945471e+07     1.916870e+08   1415.446327
# min         1.400000e+03    0.000000e+00     0.000000e+00   -100.000000
# 25%         3.750000e+06    8.966500e+03     1.523775e+05    -99.678376
# 50%         1.400000e+07    1.467767e+07     3.119242e+07    -36.803515
# 75%         3.500000e+07    4.418764e+07     9.674571e+07     67.784791
# max         3.000000e+08    4.481391e+08     1.518723e+09  22664.410000
#
#        roi_worldwide
# count     283.000000
# mean      451.475059
# std      2600.621076
# min      -100.000000
# 25%       -94.852877
# 50%        53.789757
# 75%       274.620943
# max     41556.474000

# %%
news.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count                0.0             0.0              0.0           0.0
# mean                 NaN             NaN              NaN           NaN
# std                  NaN             NaN              NaN           NaN
# min                  NaN             NaN              NaN           NaN
# 25%                  NaN             NaN              NaN           NaN
# 50%                  NaN             NaN              NaN           NaN
# 75%                  NaN             NaN              NaN           NaN
# max                  NaN             NaN              NaN           NaN
#
#        roi_worldwide
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
horror.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       2.040000e+02    2.040000e+02     2.040000e+02    204.000000
# mean        1.373209e+07    2.263528e+07     5.094954e+07    306.671491
# std         2.490176e+07    3.814158e+07     9.229224e+07   1704.275860
# min         1.400000e+03    0.000000e+00     0.000000e+00   -100.000000
# 25%         1.500000e+06    0.000000e+00     5.425625e+04   -100.000000
# 50%         5.000000e+06    6.292915e+06     1.472403e+07    -47.430284
# 75%         1.500000e+07    3.337121e+07     6.989958e+07    207.155757
# max         1.900000e+08    3.274817e+08     6.974580e+08  22664.410000
#
#        roi_worldwide
# count     204.000000
# mean      680.224530
# std      3127.356417
# min      -100.000000
# 25%       -97.853526
# 50%        34.970082
# 75%       452.901911
# max     41556.474000

# %%
mystery.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.310000e+02    1.310000e+02     1.310000e+02    131.000000
# mean        2.120983e+07    3.271739e+07     7.699765e+07    388.636582
# std         2.881741e+07    4.414103e+07     1.056531e+08   2054.181054
# min         2.500000e+04    0.000000e+00     0.000000e+00   -100.000000
# 25%         3.470000e+06    1.550670e+05     2.181078e+06    -95.711975
# 50%         1.000000e+07    1.783912e+07     3.424677e+07      0.900775
# 75%         3.000000e+07    4.607818e+07     1.009282e+08    203.940792
# max         1.850000e+08    2.544643e+08     5.864643e+08  22664.410000
#
#        roi_worldwide
# count     131.000000
# mean      874.700994
# std      3766.921913
# min      -100.000000
# 25%       -60.924172
# 50%       154.963578
# 75%       606.713208
# max     41556.474000

# %%
comedy.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       5.160000e+02    5.160000e+02     5.160000e+02    516.000000
# mean        3.496151e+07    5.068152e+07     1.168485e+08     64.279400
# std         4.143874e+07    7.039250e+07     1.876612e+08    246.433255
# min         9.000000e+03    0.000000e+00     0.000000e+00   -100.000000
# 25%         5.000000e+06    1.748863e+06     4.686195e+06    -78.223358
# 50%         2.000000e+07    2.853540e+07     4.547870e+07     -4.451199
# 75%         4.575000e+07    6.610496e+07     1.357128e+08    112.414172
# max         2.150000e+08    4.862956e+08     1.160336e+09   2662.831700
#
#        roi_worldwide
# count     516.000000
# mean      212.452916
# std       433.634034
# min      -100.000000
# 25%       -46.247884
# 50%       110.943598
# 75%       308.500667
# max      5479.296120

# %%
romance.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.920000e+02    1.920000e+02     1.920000e+02    192.000000
# mean        1.932983e+07    2.863838e+07     6.223064e+07     94.513816
# std         2.462024e+07    5.015299e+07     1.210554e+08    334.981731
# min         2.200000e+04    0.000000e+00     0.000000e+00   -100.000000
# 25%         3.200000e+06    4.329802e+05     1.962839e+06    -92.175117
# 50%         1.200000e+07    8.643843e+06     1.837675e+07    -15.762979
# 75%         2.600000e+07    4.121691e+07     7.471904e+07    143.599355
# max         1.900000e+08    5.040142e+08     1.259200e+09   2662.831700
#
#        roi_worldwide
# count     192.000000
# mean      268.200263
# std       602.518604
# min      -100.000000
# 25%       -57.651924
# 50%        85.356366
# 75%       344.544542
# max      5479.296120

# %%
sport.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       3.200000e+01    3.200000e+01     3.200000e+01     32.000000
# mean        2.577734e+07    3.926613e+07     8.284808e+07     80.933243
# std         3.126403e+07    7.484792e+07     2.265400e+08    480.614999
# min         1.750000e+05    0.000000e+00     0.000000e+00   -100.000000
# 25%         4.625000e+06    5.991582e+05     1.198441e+06    -78.933873
# 50%         1.750000e+07    1.402561e+07     1.930954e+07    -40.616089
# 75%         3.025000e+07    4.297253e+07     7.066526e+07     81.268154
# max         1.500000e+08    4.007380e+08     1.272470e+09   2662.831700
#
#        roi_worldwide
# count      32.000000
# mean      215.450126
# std       975.379877
# min      -100.000000
# 25%       -63.488283
# 50%         3.829628
# 75%       126.533648
# max      5479.296120

# %%
drama.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       7.960000e+02    7.960000e+02     7.960000e+02    796.000000
# mean        2.344892e+07    2.828257e+07     6.292277e+07     46.064828
# std         3.090895e+07    4.793699e+07     1.229878e+08    247.469016
# min         1.400000e+03    0.000000e+00     0.000000e+00   -100.000000
# 25%         4.500000e+06    2.559868e+05     1.550961e+06    -92.478997
# 50%         1.300000e+07    8.881372e+06     1.866395e+07    -37.181202
# 75%         3.000000e+07    3.747307e+07     7.023465e+07     81.305371
# max         1.900000e+08    5.040142e+08     1.272470e+09   2159.670567
#
#        roi_worldwide
# count     796.000000
# mean      177.048434
# std       425.615759
# min      -100.000000
# 25%       -74.818123
# 50%        36.631814
# 75%       238.915550
# max      4249.700800

# %%
action.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       4.250000e+02    4.250000e+02     4.250000e+02    425.000000
# mean        7.659906e+07    8.340971e+07     2.346719e+08      6.567124
# std         7.241200e+07    1.167395e+08     3.185278e+08    163.849288
# min         7.500000e+04    0.000000e+00     0.000000e+00   -100.000000
# 25%         2.000000e+07    7.696134e+06     1.827301e+07    -77.614248
# 50%         5.000000e+07    4.009806e+07     1.076506e+08    -31.892460
# 75%         1.250000e+08    1.031443e+08     3.181462e+08     30.913466
# max         4.106000e+08    7.000596e+08     2.048134e+09   1749.400600
#
#        roi_worldwide
# count     425.000000
# mean      162.285803
# std       309.919427
# min      -100.000000
# 25%       -34.366728
# 50%       103.688489
# 75%       261.178729
# max      3001.627558

# %%
biography.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.410000e+02    1.410000e+02     1.410000e+02    141.000000
# mean        2.408929e+07    3.448867e+07     7.235912e+07     57.942539
# std         2.118964e+07    5.138361e+07     1.200443e+08    226.729382
# min         2.000000e+04    0.000000e+00     0.000000e+00   -100.000000
# 25%         1.000000e+07    3.254172e+06     7.265283e+06    -76.081067
# 50%         2.000000e+07    1.586157e+07     2.731787e+07    -11.961350
# 75%         3.100000e+07    4.348227e+07     9.301734e+07    113.281275
# max         1.350000e+08    3.501264e+08     8.949853e+08   1688.777556
#
#        roi_worldwide
# count     141.000000
# mean      211.542014
# std       429.693549
# min      -100.000000
# 25%       -53.525496
# 50%        86.486551
# 75%       294.769113
# max      3001.627558

# %%
fantasy.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.160000e+02    1.160000e+02     1.160000e+02    116.000000
# mean        8.145517e+07    7.325154e+07     2.193254e+08     31.762582
# std         8.201028e+07    9.795915e+07     2.923715e+08    236.559147
# min         1.000000e+05    0.000000e+00     0.000000e+00   -100.000000
# 25%         1.635000e+07    1.272502e+07     2.563121e+07    -73.191215
# 50%         5.100000e+07    3.681796e+07     8.472072e+07    -34.143349
# 75%         1.455000e+08    8.095185e+07     2.825153e+08     22.825906
# max         4.106000e+08    5.040142e+08     1.259200e+09   1501.667320
#
#        roi_worldwide
# count     116.000000
# mean      196.958971
# std       394.558361
# min      -100.000000
# 25%         7.395738
# 50%       103.228583
# 75%       243.785181
# max      2669.782000

# %%
music.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       5.000000e+01    5.000000e+01     5.000000e+01     50.000000
# mean        1.517540e+07    3.345704e+07     7.243613e+07     74.454273
# std         1.427032e+07    5.329688e+07     1.525345e+08    190.514759
# min         1.000000e+05    0.000000e+00     0.000000e+00   -100.000000
# 25%         2.625000e+06    2.416480e+06     2.615472e+06    -74.870692
# 50%         1.150000e+07    1.247720e+07     1.654972e+07     15.048972
# 75%         2.187500e+07    4.246040e+07     6.500222e+07    124.982610
# max         5.500000e+07    2.163033e+08     8.949853e+08    655.509015
#
#        roi_worldwide
# count      50.000000
# mean      240.100775
# std       443.482068
# min      -100.000000
# 25%       -51.620653
# 50%        78.616737
# 75%       354.102596
# max      2031.755815

# %%
documentary.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       7.000000e+01    7.000000e+01     7.000000e+01     70.000000
# mean        8.190329e+06    1.589075e+07     3.002848e+07     59.798249
# std         1.446512e+07    3.746290e+07     7.481215e+07    273.870376
# min         2.000000e+04    0.000000e+00     0.000000e+00   -100.000000
# 25%         5.000000e+05    0.000000e+00     1.387000e+03   -100.000000
# 50%         1.750000e+06    2.745960e+05     1.120268e+06    -73.870486
# 75%         9.000000e+06    1.131418e+07     1.564231e+07    112.723604
# max         7.500000e+07    2.152889e+08     4.334496e+08   1189.762040
#
#        roi_worldwide
# count      70.000000
# mean      143.197764
# std       390.568477
# min      -100.000000
# 25%       -99.894442
# 50%       -47.183730
# 75%       198.817179
# max      1867.778200

# %%
crime.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       2.390000e+02    2.390000e+02     2.390000e+02    239.000000
# mean        2.920601e+07    3.174348e+07     7.346988e+07     -1.741556
# std         3.182576e+07    5.051110e+07     1.575898e+08    131.118501
# min         2.500000e+04    0.000000e+00     0.000000e+00   -100.000000
# 25%         7.750000e+06    2.127225e+05     1.920527e+06    -96.920575
# 50%         2.000000e+07    1.448203e+07     2.920438e+07    -38.480000
# 75%         4.000000e+07    4.303618e+07     8.177037e+07     32.656210
# max         2.500000e+08    3.564617e+08     1.518723e+09    786.674500
#
#        roi_worldwide
# count     239.000000
# mean       91.455087
# std       227.566492
# min      -100.000000
# 25%       -72.006610
# 50%        23.503274
# 75%       163.541025
# max      1543.458800

# %%
scifi.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.440000e+02    1.440000e+02     1.440000e+02    144.000000
# mean        8.263746e+07    1.074714e+08     2.993290e+08     41.864243
# std         8.547823e+07    1.511472e+08     4.001508e+08    201.141468
# min         7.000000e+03    0.000000e+00     0.000000e+00   -100.000000
# 25%         5.000000e+06    1.246939e+06     3.617168e+06    -83.469050
# 50%         4.000000e+07    4.628645e+07     1.317743e+08    -17.049919
# 75%         1.600000e+08    1.338402e+08     4.193567e+08     84.605004
# max         3.500000e+08    7.000596e+08     2.048134e+09   1472.396000
#
#        roi_worldwide
# count     144.000000
# mean      212.933251
# std       315.340937
# min      -100.000000
# 25%       -36.435113
# 50%       139.211968
# 75%       367.793630
# max      1473.780000

# %%
adventure.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       3.380000e+02    3.380000e+02     3.380000e+02    338.000000
# mean        1.003379e+08    1.133725e+08     3.253574e+08     13.242258
# std         7.569999e+07    1.286534e+08     3.514871e+08    119.681225
# min         2.500000e+05    0.000000e+00     0.000000e+00   -100.000000
# 25%         3.500000e+07    2.140544e+07     5.020058e+07    -62.448139
# 50%         9.000000e+07    6.521050e+07     1.986671e+08    -15.291611
# 75%         1.500000e+08    1.611893e+08     5.072870e+08     38.636720
# max         4.106000e+08    7.000596e+08     2.048134e+09    619.229100
#
#        roi_worldwide
# count     338.000000
# mean      194.898687
# std       264.066212
# min      -100.000000
# 25%        16.512527
# 50%       143.340521
# 75%       303.578881
# max      1468.021855

# %%
animation.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.000000e+02    1.000000e+02     1.000000e+02    100.000000
# mean        8.830000e+07    1.173541e+08     3.304188e+08     27.644930
# std         5.306371e+07    1.114686e+08     3.032120e+08    113.432768
# min         1.500000e+06    0.000000e+00     0.000000e+00   -100.000000
# 25%         5.000000e+07    3.945794e+07     8.593344e+07    -38.620164
# 50%         7.900000e+07    9.187994e+07     2.663004e+08      1.273960
# 75%         1.305000e+08    1.635578e+08     5.125589e+08     65.974581
# max         2.000000e+08    6.085817e+08     1.242521e+09    414.054516
#
#        roi_worldwide
# count     100.000000
# mean      250.940619
# std       311.388454
# min      -100.000000
# 25%        71.614399
# 50%       177.614470
# 75%       328.466239
# max      1468.021855

# %%
family.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       7.900000e+01    7.900000e+01     7.900000e+01     79.000000
# mean        5.998513e+07    6.327098e+07     1.557671e+08     27.413347
# std         6.403300e+07    7.406625e+07     2.179920e+08    167.184920
# min         1.250000e+05    0.000000e+00     0.000000e+00   -100.000000
# 25%         8.750000e+06    2.781626e+06     5.924108e+06    -74.074410
# 50%         3.500000e+07    4.385342e+07     6.883874e+07     -2.447953
# 75%         9.500000e+07    8.447283e+07     2.002531e+08     62.867519
# max         2.500000e+08    3.030036e+08     1.017004e+09   1092.605029
#
#        roi_worldwide
# count      79.000000
# mean      136.940733
# std       260.811153
# min      -100.000000
# 25%       -52.286523
# 50%        98.433845
# 75%       201.484049
# max      1423.023560

# %%
history.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       5.000000e+01    5.000000e+01     5.000000e+01     50.000000
# mean        3.087600e+07    3.338737e+07     7.022288e+07      8.651201
# std         3.132387e+07    4.936904e+07     9.633817e+07    143.831792
# min         1.300000e+06    0.000000e+00     6.184700e+04   -100.000000
# 25%         1.025000e+07    1.466716e+06     6.683194e+06    -86.585093
# 50%         2.125000e+07    1.087191e+07     2.679387e+07    -53.302421
# 75%         4.000000e+07    5.051261e+07     1.182538e+08     60.081565
# max         1.560000e+08    1.900683e+08     4.998374e+08    578.429148
#
#        roi_worldwide
# count      50.000000
# mean      119.143391
# std       233.089142
# min       -99.587687
# 25%       -58.569258
# 50%        53.465559
# 75%       253.094040
# max       827.086864

# %%
musical.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       8.000000e+00    8.000000e+00     8.000000e+00      8.000000
# mean        3.285000e+07    5.224842e+07     1.291605e+08    -34.010815
# std         4.213272e+07    8.495002e+07     2.097973e+08     91.246371
# min         5.000000e+05    0.000000e+00     0.000000e+00   -100.000000
# 25%         1.750000e+06    1.827000e+03     1.827000e+03    -99.908650
# 50%         5.150000e+06    1.987382e+06     2.551638e+07    -73.260501
# 75%         7.350000e+07    7.247400e+07     1.424403e+08     -6.843101
# max         9.500000e+07    2.011514e+08     5.345514e+08    111.738266
#
#        roi_worldwide
# count       8.000000
# mean      116.619506
# std       276.671380
# min      -100.000000
# 25%       -99.908650
# 50%       -51.273313
# 75%       385.908507
# max       512.379108

# %%
western.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       1.100000e+01    1.100000e+01     1.100000e+01     11.000000
# mean        5.431818e+07    3.241562e+07     8.145443e+07    -57.075234
# std         8.132413e+07    5.629899e+07     1.495473e+08     55.179199
# min         1.000000e+06    0.000000e+00     0.000000e+00   -100.000000
# 25%         5.250000e+06    1.002790e+05     6.086535e+05    -97.771578
# 50%         1.800000e+07    1.513793e+06     3.771345e+06    -84.812569
# 75%         7.500000e+07    4.760580e+07     8.548605e+07    -26.310008
# max         2.750000e+08    1.628054e+08     4.499483e+08     62.805434
#
#        roi_worldwide
# count      11.000000
# mean       -4.286050
# std       132.434358
# min      -100.000000
# 25%       -92.457310
# 50%       -48.640181
# 75%        17.664378
# max       349.948323

# %%
war.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  roi_domestic  \
# count       2.000000e+01    2.000000e+01     2.000000e+01     20.000000
# mean        2.432500e+07    1.685497e+07     4.427899e+07    -55.738092
# std         2.897153e+07    3.272215e+07     8.810923e+07     55.385663
# min         1.000000e+06    0.000000e+00     7.894800e+04   -100.000000
# 25%         9.750000e+06    1.498410e+05     4.036442e+05    -97.592620
# 50%         1.400000e+07    1.738944e+06     3.413546e+06    -84.509573
# 75%         2.137500e+07    9.540620e+06     3.214175e+07     -0.513688
# max         1.100000e+08    1.065801e+08     3.307801e+08     60.570200
#
#        roi_worldwide
# count      20.000000
# mean        3.510543
# std       124.943389
# min       -99.268392
# 25%       -91.699404
# 50%       -69.596496
# 75%        85.620946
# max       300.456374

# %%
filtered_df.reset_index(drop=True)
# Out:
#      release_date                 movie  production_budget  domestic_gross  \
# 0      2015-07-10           The Gallows             100000        22764410
# 1      2015-07-10           The Gallows             100000        22764410
# 2      2015-07-10           The Gallows             100000        22764410
# 3      2012-01-06      The Devil Inside            1000000        53262945
# 4      2011-04-01             Insidious            1500000        54009150
# ...           ...                   ...                ...             ...
# 3940   2019-12-31                Reagan           25000000               0
# 3941   2019-12-31                Reagan           25000000               0
# 3942   2015-09-29  A Plague So Pleasant               1400               0
# 3943   2015-09-29  A Plague So Pleasant               1400               0
# 3944   2015-09-29  A Plague So Pleasant               1400               0
#
#       worldwide_gross     tconst       genres  roi_domestic  roi_worldwide
# 0            41656474  tt2309260       Horror    22664.4100   41556.474000
# 1            41656474  tt2309260      Mystery    22664.4100   41556.474000
# 2            41656474  tt2309260     Thriller    22664.4100   41556.474000
# 3           101759490  tt1560985       Horror     5226.2945   10075.949000
# 4            99870886  tt1591095       Horror     3500.6100    6558.059067
# ...               ...        ...          ...           ...            ...
# 3940                0  tt1822382    Biography     -100.0000    -100.000000
# 3941                0  tt1822382  Documentary     -100.0000    -100.000000
# 3942                0  tt2107644        Drama     -100.0000    -100.000000
# 3943                0  tt2107644       Horror     -100.0000    -100.000000
# 3944                0  tt2107644     Thriller     -100.0000    -100.000000
#
# [3945 rows x 9 columns]

# %%
import seaborn as sns

# %%
fig_dims = (20, 14)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( y=filtered_df["genres"], 
            x=filtered_df["roi_worldwide"], 
            palette="Blues", 
            width=0.6, 
            showfliers = False,
            showmeans = True);

plt.xlabel("% ROI", size=14)
plt.ylabel("Movie Genres", size=14)
plt.title("Average Return On Investment Per Genre", size=18)
plt.show()

# %%
#filtered_df.drop(filtered_df[(filtered_df['genres'] =='Crime') | (filtered_df['genres'] == 'Sport')].index, inplace=True)
#filtered_df

#this works, it just seems innefficient to type out 17 genres

# %%
#top_5 = ['animation', 'mystery', 'adventure', 'sci-fi', 'comedy']

#for index, row in filtered_df.iterrows():
#    for top in top_5:
#        if row['genres'] != top :
#            filtered_df.drop(index, inplace=True)
#filtered_df

# %%
filtered_df.shape
# Out:
# (3945, 9)

# %%
#top_5 = ['animation', 'mystery', 'adventure', 'sci-fi', 'comedy']
top_5_df = adventure.append(animation)

# %%
top_5_df = top_5_df.append(comedy)
top_5_df
# Out:
#      release_date                     movie  production_budget  \
# 801    2015-07-10                   Minions           74000000
# 4705   2019-01-16  Dragon Ball Super: Broly            8500000
# 1136   2016-02-12                  Deadpool           58000000
# 739    2017-06-30           Despicable Me 3           75000000
# 6466   2015-09-25         The Green Inferno            1000000
# ...           ...                       ...                ...
# 5400   2016-03-15              The Hatching            5000000
# 5398   2015-12-31             Aztec Warrior            5000000
# 5397   2012-12-31      Should've Been Romeo            5000000
# 5394   2015-01-09    Let's Kill Ward's Wife            5000000
# 5391   2014-11-21                  Reach Me            5000000
#
#       domestic_gross  worldwide_gross     tconst     genres  roi_domestic  \
# 801        336045770       1160336173  tt2293640  Adventure    354.115905
# 4705        30376755        122747755  tt7961060  Adventure    257.373588
# 1136       363070709        801025593  tt1431045  Adventure    525.983981
# 739        264624300       1034727750  tt3469046  Adventure    252.832400
# 6466         7192291         12931420  tt2403021  Adventure    619.229100
# ...              ...              ...        ...        ...           ...
# 5400               0                0  tt2938464     Comedy   -100.000000
# 5398               0                0  tt2237914     Comedy   -100.000000
# 5397               0                0  tt1717210     Comedy   -100.000000
# 5394               0                0  tt2980708     Comedy   -100.000000
# 5391               0                0  tt0959306     Comedy   -100.000000
#
#       roi_worldwide
# 801     1468.021855
# 4705    1344.091235
# 1136    1281.078609
# 739     1279.637000
# 6466    1193.142000
# ...             ...
# 5400    -100.000000
# 5398    -100.000000
# 5397    -100.000000
# 5394    -100.000000
# 5391    -100.000000
#
# [954 rows x 9 columns]

# %%
top_5_df = top_5_df.append(mystery)
top_5_df
# Out:
#      release_date                     movie  production_budget  \
# 801    2015-07-10                   Minions           74000000
# 4705   2019-01-16  Dragon Ball Super: Broly            8500000
# 1136   2016-02-12                  Deadpool           58000000
# 739    2017-06-30           Despicable Me 3           75000000
# 6466   2015-09-25         The Green Inferno            1000000
# ...           ...                       ...                ...
# 6670   2012-12-31                     After             650000
# 6558   2012-10-09              Truth or Die            1000000
# 6326   2015-09-08                 Checkmate            1500000
# 6415   2012-09-07                 Crowsnest            1200000
# 3005   2019-02-01            Velvet Buzzsaw           21000000
#
#       domestic_gross  worldwide_gross     tconst     genres  roi_domestic  \
# 801        336045770       1160336173  tt2293640  Adventure    354.115905
# 4705        30376755        122747755  tt7961060  Adventure    257.373588
# 1136       363070709        801025593  tt1431045  Adventure    525.983981
# 739        264624300       1034727750  tt3469046  Adventure    252.832400
# 6466         7192291         12931420  tt2403021  Adventure    619.229100
# ...              ...              ...        ...        ...           ...
# 6670               0                0  tt1147681    Mystery   -100.000000
# 6558               0                0  tt1838722    Mystery   -100.000000
# 6326               0                0  tt1675846    Mystery   -100.000000
# 6415               0                0  tt2180333    Mystery   -100.000000
# 3005               0                0  tt7043012    Mystery   -100.000000
#
#       roi_worldwide
# 801     1468.021855
# 4705    1344.091235
# 1136    1281.078609
# 739     1279.637000
# 6466    1193.142000
# ...             ...
# 6670    -100.000000
# 6558    -100.000000
# 6326    -100.000000
# 6415    -100.000000
# 3005    -100.000000
#
# [1085 rows x 9 columns]

# %%
top_5_df = top_5_df.append(scifi)
top_5_df
# Out:
#      release_date                     movie  production_budget  \
# 801    2015-07-10                   Minions           74000000
# 4705   2019-01-16  Dragon Ball Super: Broly            8500000
# 1136   2016-02-12                  Deadpool           58000000
# 739    2017-06-30           Despicable Me 3           75000000
# 6466   2015-09-25         The Green Inferno            1000000
# ...           ...                       ...                ...
# 4041   2012-03-30                      Womb           13000000
# 5611   2015-12-31                  The Veil            4000000
# 5609   2012-11-09                  Replicas            4000000
# 5979   2013-06-21            Alien Uprising            2500000
# 6324   2015-05-26              Mutant World            1500000
#
#       domestic_gross  worldwide_gross     tconst     genres  roi_domestic  \
# 801        336045770       1160336173  tt2293640  Adventure    354.115905
# 4705        30376755        122747755  tt7961060  Adventure    257.373588
# 1136       363070709        801025593  tt1431045  Adventure    525.983981
# 739        264624300       1034727750  tt3469046  Adventure    252.832400
# 6466         7192291         12931420  tt2403021  Adventure    619.229100
# ...              ...              ...        ...        ...           ...
# 4041               0                0  tt1216520     Sci-Fi   -100.000000
# 5611               0                0  tt3343868     Sci-Fi   -100.000000
# 5609               0                0  tt4154916     Sci-Fi   -100.000000
# 5979               0                0  tt2040578     Sci-Fi   -100.000000
# 6324               0                0  tt3626436     Sci-Fi   -100.000000
#
#       roi_worldwide
# 801     1468.021855
# 4705    1344.091235
# 1136    1281.078609
# 739     1279.637000
# 6466    1193.142000
# ...             ...
# 4041    -100.000000
# 5611    -100.000000
# 5609    -100.000000
# 5979    -100.000000
# 6324    -100.000000
#
# [1229 rows x 9 columns]

# %%
top_5_df['genres'].unique()
# Out:
# array(['Adventure', 'Animation', 'Comedy', 'Mystery', 'Sci-Fi'],
#       dtype=object)

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( x=top_5_df["genres"], 
            y=top_5_df["roi_worldwide"], 
            palette="Blues", 
            width=0.6, 
            showfliers = False, 
            showmeans=True);


plt.ylabel("% ROI", size=14)
plt.xlabel("Movie Genres", size=14)
plt.title("Average Return On Investment For The Top 5 Genres", size=18)
ax.yaxis.grid(False) # Hide the horizontal gridlines
ax.xaxis.grid(False) # Hide the vertical gridlines

sns.despine(offset=10, trim=True)
plt.show()

# %%
arr = adventure['roi_worldwide']
arr2 = animation['roi_worldwide']
arr3 = comedy['roi_worldwide']
arr4 = mystery['roi_worldwide']
arr5 = scifi['roi_worldwide']
print(f'Adventure ROI: \n  Worst Case = {int(np.percentile(arr, 25))}% \n  Base Case = {int(np.percentile(arr, 50))}% \n  Best Case = {int(np.percentile(arr, 75))}%')
print(f'Animation ROI: \n  Worst Case = {int(np.percentile(arr2, 25))}% \n  Base Case = {int(np.percentile(arr2, 50))}% \n  Best Case = {int(np.percentile(arr2, 75))}%')
print(f'Comedy ROI: \n  Worst Case = {int(np.percentile(arr3, 25))}% \n  Base Case = {int(np.percentile(arr3, 50))}% \n  Best Case = {int(np.percentile(arr3, 75))}%')
print(f'Mystery ROI: \n  Worst Case = {int(np.percentile(arr4, 25))}% \n  Base Case = {int(np.percentile(arr4, 50))}% \n  Best Case = {int(np.percentile(arr4, 75))}%')
print(f'Sci-fi ROI: \n  Worst Case = {int(np.percentile(arr5, 25))}% \n  Base Case = {int(np.percentile(arr5, 50))}% \n  Best Case = {int(np.percentile(arr5, 75))}%')
# Out:
# Adventure ROI:
#   Worst Case = 16%
#   Base Case = 143%
#   Best Case = 303%
# Animation ROI:
#   Worst Case = 71%
#   Base Case = 177%
#   Best Case = 328%
# Comedy ROI:
#   Worst Case = -46%
#   Base Case = 110%
#   Best Case = 308%
# Mystery ROI:
#   Worst Case = -60%
#   Base Case = 154%
#   Best Case = 606%
# Sci-fi ROI:
#   Worst Case = -36%
#   Base Case = 139%
#   Best Case = 367%

# %%
fig_dims = (20, 14)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( y=filtered_df["genres"], 
            x=filtered_df["roi_domestic"], 
            palette="Blues", 
            width=0.6, 
            showfliers = False, 
            showmeans=True);

plt.xlabel("% ROI", size=14)
plt.ylabel("Movie Genres", size=14)
plt.title("Average Return On Investment Per Genre", size=18)
plt.show()

# %%
top_5_df_domestic= animation.append(comedy)

# %%
top_5_df_domestic = top_5_df_domestic.append(family)

# %%
top_5_df_domestic = top_5_df_domestic.append(music)

# %%
top_5_df_domestic = top_5_df_domestic.append(mystery)

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot( x=top_5_df_domestic["genres"], 
            y=top_5_df_domestic["roi_domestic"], 
            palette="Blues", 
            width=0.6, 
            showfliers = False, 
            showmeans=True,
            data=top_5_df_domestic.groupby('roi_domestic', as_index=False).median());

plt.ylabel("% ROI", size=14)
plt.xlabel("Movie Genres", size=14)
plt.title("Average Return On Investment For The Top 5 Genres", size=18)
#sns.stripplot(x="genres", y="roi_domestic", data=top_5_df_domestic)
ax.yaxis.grid(False) # Hide the horizontal gridlines
ax.xaxis.grid(False) # Show the vertical gridlines
sns.despine(offset=10, trim=True)
plt.show()

# %%
arr = animation['roi_domestic']
arr2 = comedy['roi_domestic']
arr3 = family['roi_domestic']
arr4 = music['roi_domestic']
arr5 = mystery['roi_domestic']
print(f'Animation ROI: \n  Worst Case = {int(np.percentile(arr, 25))}% \n  Base Case = {int(np.percentile(arr, 50))}% \n  Best Case = {int(np.percentile(arr, 75))}%')
print(f'Comedy ROI: \n  Worst Case = {int(np.percentile(arr2, 25))}% \n  Base Case = {int(np.percentile(arr2, 50))}% \n  Best Case = {int(np.percentile(arr2, 75))}%')
print(f'Family ROI: \n  Worst Case = {int(np.percentile(arr3, 25))}% \n  Base Case = {int(np.percentile(arr3, 50))}% \n  Best Case = {int(np.percentile(arr3, 75))}%')
print(f'Music ROI: \n  Worst Case = {int(np.percentile(arr4, 25))}% \n  Base Case = {int(np.percentile(arr4, 50))}% \n  Best Case = {int(np.percentile(arr4, 75))}%')
print(f'Mystery ROI: \n  Worst Case = {int(np.percentile(arr5, 25))}% \n  Base Case = {int(np.percentile(arr5, 50))}% \n  Best Case = {int(np.percentile(arr5, 75))}%')
# Out:
# Animation ROI:
#   Worst Case = -38%
#   Base Case = 1%
#   Best Case = 65%
# Comedy ROI:
#   Worst Case = -78%
#   Base Case = -4%
#   Best Case = 112%
# Family ROI:
#   Worst Case = -74%
#   Base Case = -2%
#   Best Case = 62%
# Music ROI:
#   Worst Case = -74%
#   Base Case = 15%
#   Best Case = 124%
# Mystery ROI:
#   Worst Case = -95%
#   Base Case = 0%
#   Best Case = 203%
